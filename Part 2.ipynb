# %%
import pandas as pd

# %% [markdown]
# # Create Data Frame

# %%
# 10-01-11
# dept-position-number

# series
emp_id = [100111,100112,200210,200211,200312,300207]
emp_name = [
    'Raven Bierman',
    'Valter Havers',
    'Marko Mendell',
    'Takahiro Momota',
    'Yahiko Tilemans',
    'Dina Rebaine'
]
gender = ['Female','Male','Male','Male','Male','Female']
hire_date = [
    '2016-12-04',
    '2018-04-13',
    '2018-07-04',
    '2016-11-18',
    '2017-05-26',
    '2015-03-20'
]
salary = [7000000,7000000,15000000,12000000,20000000,15000000]

# dictionary
dict_emp = {
    'name':emp_name,
    'gender':gender,
    'hire date':hire_date,
    'gross salary':salary
}

# dataframe
df = pd.DataFrame(dict_emp, index = emp_id)

# %%
df
# Out:
#                    name  gender   hire date  gross salary
# 100111    Raven Bierman  Female  2016-12-04       7000000
# 100112    Valter Havers    Male  2018-04-13       7000000
# 200210    Marko Mendell    Male  2018-07-04      15000000
# 200211  Takahiro Momota    Male  2016-11-18      12000000
# 200312  Yahiko Tilemans    Male  2017-05-26      20000000
# 300207     Dina Rebaine  Female  2015-03-20      15000000

# %% [markdown]
# # Selection

# %% [markdown]
# > column selection

# %%
df['name']
# Out:
# 100111      Raven Bierman
# 100112      Valter Havers
# 200210      Marko Mendell
# 200211    Takahiro Momota
# 200312    Yahiko Tilemans
# 300207       Dina Rebaine
# Name: name, dtype: object

# %%
df.name
# Out:
# 100111      Raven Bierman
# 100112      Valter Havers
# 200210      Marko Mendell
# 200211    Takahiro Momota
# 200312    Yahiko Tilemans
# 300207       Dina Rebaine
# Name: name, dtype: object

# %%
df[['name','gross salary']]
# Out:
#                    name  gross salary
# 100111    Raven Bierman       7000000
# 100112    Valter Havers       7000000
# 200210    Marko Mendell      15000000
# 200211  Takahiro Momota      12000000
# 200312  Yahiko Tilemans      20000000
# 300207     Dina Rebaine      15000000

# %%
select_var = ['name','gender','gross salary']

df[select_var]
# Out:
#                    name  gender  gross salary
# 100111    Raven Bierman  Female       7000000
# 100112    Valter Havers    Male       7000000
# 200210    Marko Mendell    Male      15000000
# 200211  Takahiro Momota    Male      12000000
# 200312  Yahiko Tilemans    Male      20000000
# 300207     Dina Rebaine  Female      15000000

# %%
df.loc[:,select_var]
# Out:
#                    name  gender  gross salary
# 100111    Raven Bierman  Female       7000000
# 100112    Valter Havers    Male       7000000
# 200210    Marko Mendell    Male      15000000
# 200211  Takahiro Momota    Male      12000000
# 200312  Yahiko Tilemans    Male      20000000
# 300207     Dina Rebaine  Female      15000000

# %%
df.iloc[:,0]
# Out:
# 100111      Raven Bierman
# 100112      Valter Havers
# 200210      Marko Mendell
# 200211    Takahiro Momota
# 200312    Yahiko Tilemans
# 300207       Dina Rebaine
# Name: name, dtype: object

# %%
df.iloc[:,[0,2]]
# Out:
#                    name   hire date
# 100111    Raven Bierman  2016-12-04
# 100112    Valter Havers  2018-04-13
# 200210    Marko Mendell  2018-07-04
# 200211  Takahiro Momota  2016-11-18
# 200312  Yahiko Tilemans  2017-05-26
# 300207     Dina Rebaine  2015-03-20

# %% [markdown]
# > row selection

# %%
df[0:1]
# Out:
#                  name  gender   hire date  gross salary
# 100111  Raven Bierman  Female  2016-12-04       7000000

# %%
df[1:4]
# Out:
#                    name gender   hire date  gross salary
# 100112    Valter Havers   Male  2018-04-13       7000000
# 200210    Marko Mendell   Male  2018-07-04      15000000
# 200211  Takahiro Momota   Male  2016-11-18      12000000

# %%
df.loc[[100112,200211],:]
# Out:
#                    name gender   hire date  gross salary
# 100112    Valter Havers   Male  2018-04-13       7000000
# 200211  Takahiro Momota   Male  2016-11-18      12000000

# %%
df.iloc[[1,4],:]
# Out:
#                    name gender   hire date  gross salary
# 100112    Valter Havers   Male  2018-04-13       7000000
# 200312  Yahiko Tilemans   Male  2017-05-26      20000000

# %% [markdown]
# > combine row and column selection

# %%
df.loc[100112,'name']
# Out:
# 'Valter Havers'

# %%
df.iloc[1,0]
# Out:
# 'Valter Havers'

# %%
df.loc[[100112,200210],['name','gender','hire date']]
# Out:
#                  name gender   hire date
# 100112  Valter Havers   Male  2018-04-13
# 200210  Marko Mendell   Male  2018-07-04

# %%
df.iloc[1:3,0:3]
# Out:
#                  name gender   hire date
# 100112  Valter Havers   Male  2018-04-13
# 200210  Marko Mendell   Male  2018-07-04

# %% [markdown]
# > conditional selection

# %%
df
# Out:
#                    name  gender   hire date  gross salary
# 100111    Raven Bierman  Female  2016-12-04       7000000
# 100112    Valter Havers    Male  2018-04-13       7000000
# 200210    Marko Mendell    Male  2018-07-04      15000000
# 200211  Takahiro Momota    Male  2016-11-18      12000000
# 200312  Yahiko Tilemans    Male  2017-05-26      20000000
# 300207     Dina Rebaine  Female  2015-03-20      15000000

# %%
df['name'] == 'Raven Bierman'
# Out:
# 100111     True
# 100112    False
# 200210    False
# 200211    False
# 200312    False
# 300207    False
# Name: name, dtype: bool

# %%
df['gender'] == 'Male'
# Out:
# 100111    False
# 100112     True
# 200210     True
# 200211     True
# 200312     True
# 300207    False
# Name: gender, dtype: bool

# %%
df[df['name'] == 'Raven Bierman']
# Out:
#                  name  gender   hire date  gross salary
# 100111  Raven Bierman  Female  2016-12-04       7000000

# %%
df[df['gender'] == 'Male']
# Out:
#                    name gender   hire date  gross salary
# 100112    Valter Havers   Male  2018-04-13       7000000
# 200210    Marko Mendell   Male  2018-07-04      15000000
# 200211  Takahiro Momota   Male  2016-11-18      12000000
# 200312  Yahiko Tilemans   Male  2017-05-26      20000000

# %%
df[df['gender'] == 'Female']
# Out:
#                  name  gender   hire date  gross salary
# 100111  Raven Bierman  Female  2016-12-04       7000000
# 300207   Dina Rebaine  Female  2015-03-20      15000000

# %%
df[(df['gender'] == 'Male')&(df['gross salary']>10000000)]
# Out:
#                    name gender   hire date  gross salary
# 200210    Marko Mendell   Male  2018-07-04      15000000
# 200211  Takahiro Momota   Male  2016-11-18      12000000
# 200312  Yahiko Tilemans   Male  2017-05-26      20000000

# %%
df[(df['gender'] == 'Male')&(df['gross salary']>10000000)]['name']
# Out:
# 200210      Marko Mendell
# 200211    Takahiro Momota
# 200312    Yahiko Tilemans
# Name: name, dtype: object

# %% [markdown]
# # Addition

# %%
df_edit = df.copy()

# %% [markdown]
# > adding rows

# %%
# series
emp_no = [200115,100214]
emp_name = [
    'Alicia Stark',
    'John Norton',

]
gender = ['Female','Male']
hire_date = [
    '2020-05-29',
    '2020-05-29'
]
salary = [7000000,12000000]

# dictionary
dict_emp = {
    'name':emp_name,
    'gender':gender,
    'hire date':hire_date,
    'gross salary':salary
}

df_new = pd.DataFrame(dict_emp)
df_new.index = emp_no

# %%
df_edit = df_edit.append(df_new)
df_edit
# Out:
#                    name  gender   hire date  gross salary
# 100111    Raven Bierman  Female  2016-12-04       7000000
# 100112    Valter Havers    Male  2018-04-13       7000000
# 200210    Marko Mendell    Male  2018-07-04      15000000
# 200211  Takahiro Momota    Male  2016-11-18      12000000
# 200312  Yahiko Tilemans    Male  2017-05-26      20000000
# 300207     Dina Rebaine  Female  2015-03-20      15000000
# 200115     Alicia Stark  Female  2020-05-29       7000000
# 100214      John Norton    Male  2020-05-29      12000000

# %% [markdown]
# > adding columns

# %%
df_edit['nett salary'] = df_edit['gross salary'] - df_edit['gross salary']*0.10

# %%
df_edit
# Out:
#                    name  gender   hire date  gross salary  nett salary
# 100111    Raven Bierman  Female  2016-12-04       7000000    6300000.0
# 100112    Valter Havers    Male  2018-04-13       7000000    6300000.0
# 200210    Marko Mendell    Male  2018-07-04      15000000   13500000.0
# 200211  Takahiro Momota    Male  2016-11-18      12000000   10800000.0
# 200312  Yahiko Tilemans    Male  2017-05-26      20000000   18000000.0
# 300207     Dina Rebaine  Female  2015-03-20      15000000   13500000.0
# 200115     Alicia Stark  Female  2020-05-29       7000000    6300000.0
# 100214      John Norton    Male  2020-05-29      12000000   10800000.0

# %% [markdown]
# # Deletion

# %% [markdown]
# > remove columns

# %%
df_edit.drop('nett salary', axis = 1)
# Out:
#                    name  gender   hire date  gross salary
# 100111    Raven Bierman  Female  2016-12-04       7000000
# 100112    Valter Havers    Male  2018-04-13       7000000
# 200210    Marko Mendell    Male  2018-07-04      15000000
# 200211  Takahiro Momota    Male  2016-11-18      12000000
# 200312  Yahiko Tilemans    Male  2017-05-26      20000000
# 300207     Dina Rebaine  Female  2015-03-20      15000000
# 200115     Alicia Stark  Female  2020-05-29       7000000
# 100214      John Norton    Male  2020-05-29      12000000

# %%
df_edit.drop(['hire date','gender'], axis = 1)
# Out:
#                    name  gross salary  nett salary
# 100111    Raven Bierman       7000000    6300000.0
# 100112    Valter Havers       7000000    6300000.0
# 200210    Marko Mendell      15000000   13500000.0
# 200211  Takahiro Momota      12000000   10800000.0
# 200312  Yahiko Tilemans      20000000   18000000.0
# 300207     Dina Rebaine      15000000   13500000.0
# 200115     Alicia Stark       7000000    6300000.0
# 100214      John Norton      12000000   10800000.0

# %%
df_edit
# Out:
#                    name  gender   hire date  gross salary  nett salary
# 100111    Raven Bierman  Female  2016-12-04       7000000    6300000.0
# 100112    Valter Havers    Male  2018-04-13       7000000    6300000.0
# 200210    Marko Mendell    Male  2018-07-04      15000000   13500000.0
# 200211  Takahiro Momota    Male  2016-11-18      12000000   10800000.0
# 200312  Yahiko Tilemans    Male  2017-05-26      20000000   18000000.0
# 300207     Dina Rebaine  Female  2015-03-20      15000000   13500000.0
# 200115     Alicia Stark  Female  2020-05-29       7000000    6300000.0
# 100214      John Norton    Male  2020-05-29      12000000   10800000.0

# %%
df_edit.drop('nett salary', axis = 1, inplace = True)

# %% [markdown]
# > remove rows

# %%
df_edit.drop(100111, axis = 0)
# Out:
#                    name  gender   hire date  gross salary
# 100112    Valter Havers    Male  2018-04-13       7000000
# 200210    Marko Mendell    Male  2018-07-04      15000000
# 200211  Takahiro Momota    Male  2016-11-18      12000000
# 200312  Yahiko Tilemans    Male  2017-05-26      20000000
# 300207     Dina Rebaine  Female  2015-03-20      15000000
# 200115     Alicia Stark  Female  2020-05-29       7000000
# 100214      John Norton    Male  2020-05-29      12000000

# %%
df_edit.drop([200312,300207], axis = 0)
# Out:
#                    name  gender   hire date  gross salary
# 100111    Raven Bierman  Female  2016-12-04       7000000
# 100112    Valter Havers    Male  2018-04-13       7000000
# 200210    Marko Mendell    Male  2018-07-04      15000000
# 200211  Takahiro Momota    Male  2016-11-18      12000000
# 200115     Alicia Stark  Female  2020-05-29       7000000
# 100214      John Norton    Male  2020-05-29      12000000

# %%
df_edit
# Out:
#                    name  gender   hire date  gross salary
# 100111    Raven Bierman  Female  2016-12-04       7000000
# 100112    Valter Havers    Male  2018-04-13       7000000
# 200210    Marko Mendell    Male  2018-07-04      15000000
# 200211  Takahiro Momota    Male  2016-11-18      12000000
# 200312  Yahiko Tilemans    Male  2017-05-26      20000000
# 300207     Dina Rebaine  Female  2015-03-20      15000000
# 200115     Alicia Stark  Female  2020-05-29       7000000
# 100214      John Norton    Male  2020-05-29      12000000

# %%
df_edit.drop([200312,300207], axis = 0, inplace = True)

# %%
df_edit
# Out:
#                    name  gender   hire date  gross salary
# 100111    Raven Bierman  Female  2016-12-04       7000000
# 100112    Valter Havers    Male  2018-04-13       7000000
# 200210    Marko Mendell    Male  2018-07-04      15000000
# 200211  Takahiro Momota    Male  2016-11-18      12000000
# 200115     Alicia Stark  Female  2020-05-29       7000000
# 100214      John Norton    Male  2020-05-29      12000000

# %% [markdown]
# # Renaming

# %% [markdown]
# > index

# %%
# 10-01-11
# dept-position-number

# series
emp_name = [
    'Raven Bierman',
    'Valter Havers',
    'Marko Mendell',
    'Takahiro Momota',
    'Yahiko Tilemans',
    'Dina Rebaine'
]
gender = ['Female','Male','Male','Male','Male','Female']
hire_date = [
    '2016-12-04',
    '2018-04-13',
    '2018-07-04',
    '2016-11-18',
    '2017-05-26',
    '2015-03-20'
]
salary = [7000000,7000000,15000000,12000000,20000000,15000000]

# dictionary
dict_emp = {
    'name':emp_name,
    'gender':gender,
    'hire date':hire_date,
    'gross salary':salary
}

# dataframe
df = pd.DataFrame(dict_emp)

# %%
df
# Out:
#               name  gender   hire date  gross salary
# 0    Raven Bierman  Female  2016-12-04       7000000
# 1    Valter Havers    Male  2018-04-13       7000000
# 2    Marko Mendell    Male  2018-07-04      15000000
# 3  Takahiro Momota    Male  2016-11-18      12000000
# 4  Yahiko Tilemans    Male  2017-05-26      20000000
# 5     Dina Rebaine  Female  2015-03-20      15000000

# %%
emp_no = [100111,100112,200210,200211,200312,300207]

# %%
dept_no = ['10','10','20','20','20','30']
level = ['01','01','02','02','03','02']
emp_no = ['11','12','10','11','12','07']

hire_index = list(zip(dept_no, level, emp_no))
hire_index = pd.MultiIndex.from_tuples(hire_index)

# %%
hire_index
# Out:
# MultiIndex(levels=[['10', '20', '30'], ['01', '02', '03'], ['07', '10', '11', '12']],
#            codes=[[0, 0, 1, 1, 1, 2], [0, 0, 1, 1, 2, 1], [2, 3, 1, 2, 3, 0]])

# %%
# 10-01-11
# dept-position-number

# series
emp_name = [
    'Raven Bierman',
    'Valter Havers',
    'Marko Mendell',
    'Takahiro Momota',
    'Yahiko Tilemans',
    'Dina Rebaine'
]
gender = ['Female','Male','Male','Male','Male','Female']
hire_date = [
    '2016-12-04',
    '2018-04-13',
    '2018-07-04',
    '2016-11-18',
    '2017-05-26',
    '2015-03-20'
]
salary = [7000000,7000000,15000000,12000000,20000000,15000000]

# dictionary
dict_emp = {
    'name':emp_name,
    'gender':gender,
    'hire date':hire_date,
    'gross salary':salary
}

# dataframe
df = pd.DataFrame(dict_emp, index = hire_index)

# %%
df
# Out:
#                      name  gender   hire date  gross salary
# 10 01 11    Raven Bierman  Female  2016-12-04       7000000
#       12    Valter Havers    Male  2018-04-13       7000000
# 20 02 10    Marko Mendell    Male  2018-07-04      15000000
#       11  Takahiro Momota    Male  2016-11-18      12000000
#    03 12  Yahiko Tilemans    Male  2017-05-26      20000000
# 30 02 07     Dina Rebaine  Female  2015-03-20      15000000

# %%
dept_no = ['Data','Data','HR','HR','HR','Engineering']
level = ['staff','staff','manager','manager','geral manager','manager']
emp_no = ['11','12','10','11','12','07']

hire_index = list(zip(dept_no, level, emp_no))
hire_index = pd.MultiIndex.from_tuples(hire_index)

# %%
hire_index
# Out:
# MultiIndex(levels=[['Data', 'Engineering', 'HR'], ['geral manager', 'manager', 'staff'], ['07', '10', '11', '12']],
#            codes=[[0, 0, 2, 2, 2, 1], [2, 2, 1, 1, 0, 1], [2, 3, 1, 2, 3, 0]])

# %%
# 10-01-11
# dept-position-number

# series
emp_name = [
    'Raven Bierman',
    'Valter Havers',
    'Marko Mendell',
    'Takahiro Momota',
    'Yahiko Tilemans',
    'Dina Rebaine'
]
gender = ['Female','Male','Male','Male','Male','Female']
hire_date = [
    '2016-12-04',
    '2018-04-13',
    '2018-07-04',
    '2016-11-18',
    '2017-05-26',
    '2015-03-20'
]
salary = [7000000,7000000,15000000,12000000,20000000,15000000]

# dictionary
dict_emp = {
    'name':emp_name,
    'gender':gender,
    'hire date':hire_date,
    'gross salary':salary
}

# dataframe
df = pd.DataFrame(dict_emp, index = hire_index)

# %%
df
# Out:
#                                          name  gender   hire date  \
# Data        staff         11    Raven Bierman  Female  2016-12-04
#                           12    Valter Havers    Male  2018-04-13
# HR          manager       10    Marko Mendell    Male  2018-07-04
#                           11  Takahiro Momota    Male  2016-11-18
#             geral manager 12  Yahiko Tilemans    Male  2017-05-26
# Engineering manager       07     Dina Rebaine  Female  2015-03-20
#
#                               gross salary
# Data        staff         11       7000000
#                           12       7000000
# HR          manager       10      15000000
#                           11      12000000
#             geral manager 12      20000000
# Engineering manager       07      15000000

# %% [markdown]
# > columns

# %%
df.columns
# Out:
# Index(['name', 'gender', 'hire date', 'gross salary'], dtype='object')

# %%
df.columns = ['name', 'gender', 'hire_date', 'gross_salary']

# %% [markdown]
# # Sorting

# %%
# 10-01-11
# dept-position-number

# series
emp_id = [100111,100112,200210,200211,200312,300207]
emp_name = [
    'Raven Bierman',
    'Valter Havers',
    'Marko Mendell',
    'Takahiro Momota',
    'Yahiko Tilemans',
    'Dina Rebaine'
]
gender = ['Female','Male','Male','Male','Male','Female']
hire_date = [
    '2016-12-04',
    '2018-04-13',
    '2018-07-04',
    '2016-11-18',
    '2017-05-26',
    '2015-03-20'
]
salary = [7000000,7000000,15000000,12000000,20000000,15000000]

# dictionary
dict_emp = {
    'name':emp_name,
    'gender':gender,
    'hire date':hire_date,
    'gross salary':salary
}

# dataframe
df = pd.DataFrame(dict_emp, index = emp_id)

# %% [markdown]
# > rows

# %%
df
# Out:
#                    name  gender   hire date  gross salary
# 100111    Raven Bierman  Female  2016-12-04       7000000
# 100112    Valter Havers    Male  2018-04-13       7000000
# 200210    Marko Mendell    Male  2018-07-04      15000000
# 200211  Takahiro Momota    Male  2016-11-18      12000000
# 200312  Yahiko Tilemans    Male  2017-05-26      20000000
# 300207     Dina Rebaine  Female  2015-03-20      15000000

# %%
df.sort_index()
# Out:
#                    name  gender   hire date  gross salary
# 100111    Raven Bierman  Female  2016-12-04       7000000
# 100112    Valter Havers    Male  2018-04-13       7000000
# 200210    Marko Mendell    Male  2018-07-04      15000000
# 200211  Takahiro Momota    Male  2016-11-18      12000000
# 200312  Yahiko Tilemans    Male  2017-05-26      20000000
# 300207     Dina Rebaine  Female  2015-03-20      15000000

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#                    name  gender   hire date  gross salary
# 100111    Raven Bierman  Female  2016-12-04       7000000
# 100112    Valter Havers    Male  2018-04-13       7000000
# 200210    Marko Mendell    Male  2018-07-04      15000000
# 200211  Takahiro Momota    Male  2016-11-18      12000000
# 200312  Yahiko Tilemans    Male  2017-05-26      20000000
# 300207     Dina Rebaine  Female  2015-03-20      15000000

# %%
df.sort_values('name')
# Out:
#                    name  gender   hire date  gross salary
# 300207     Dina Rebaine  Female  2015-03-20      15000000
# 200210    Marko Mendell    Male  2018-07-04      15000000
# 100111    Raven Bierman  Female  2016-12-04       7000000
# 200211  Takahiro Momota    Male  2016-11-18      12000000
# 100112    Valter Havers    Male  2018-04-13       7000000
# 200312  Yahiko Tilemans    Male  2017-05-26      20000000

# %%
df.sort_values('name',ascending = False)
# Out:
#                    name  gender   hire date  gross salary
# 200312  Yahiko Tilemans    Male  2017-05-26      20000000
# 100112    Valter Havers    Male  2018-04-13       7000000
# 200211  Takahiro Momota    Male  2016-11-18      12000000
# 100111    Raven Bierman  Female  2016-12-04       7000000
# 200210    Marko Mendell    Male  2018-07-04      15000000
# 300207     Dina Rebaine  Female  2015-03-20      15000000

# %%
df.sort_values('name',ascending = False,inplace=True)

# %%
df
# Out:
#                    name  gender   hire date  gross salary
# 200312  Yahiko Tilemans    Male  2017-05-26      20000000
# 100112    Valter Havers    Male  2018-04-13       7000000
# 200211  Takahiro Momota    Male  2016-11-18      12000000
# 100111    Raven Bierman  Female  2016-12-04       7000000
# 200210    Marko Mendell    Male  2018-07-04      15000000
# 300207     Dina Rebaine  Female  2015-03-20      15000000

# %%
df.sort_values(by = ['gender','name'])
# Out:
#                    name  gender   hire date  gross salary
# 300207     Dina Rebaine  Female  2015-03-20      15000000
# 100111    Raven Bierman  Female  2016-12-04       7000000
# 200210    Marko Mendell    Male  2018-07-04      15000000
# 200211  Takahiro Momota    Male  2016-11-18      12000000
# 100112    Valter Havers    Male  2018-04-13       7000000
# 200312  Yahiko Tilemans    Male  2017-05-26      20000000

# %%
df.sort_values(by = ['gender','name'],
    ascending = [False,False])
# Out:
#                    name  gender   hire date  gross salary
# 200312  Yahiko Tilemans    Male  2017-05-26      20000000
# 100112    Valter Havers    Male  2018-04-13       7000000
# 200211  Takahiro Momota    Male  2016-11-18      12000000
# 200210    Marko Mendell    Male  2018-07-04      15000000
# 100111    Raven Bierman  Female  2016-12-04       7000000
# 300207     Dina Rebaine  Female  2015-03-20      15000000

# %%
df.sort_values(
    by = ['gender','name'],
    ascending = [False,False],
    inplace = True
)

# %%
df
# Out:
#                    name  gender   hire date  gross salary
# 200312  Yahiko Tilemans    Male  2017-05-26      20000000
# 100112    Valter Havers    Male  2018-04-13       7000000
# 200211  Takahiro Momota    Male  2016-11-18      12000000
# 200210    Marko Mendell    Male  2018-07-04      15000000
# 100111    Raven Bierman  Female  2016-12-04       7000000
# 300207     Dina Rebaine  Female  2015-03-20      15000000

# %%
df.sort_values(by = ['gender','name'],ascending = [True,False])
# Out:
#                    name  gender   hire date  gross salary
# 100111    Raven Bierman  Female  2016-12-04       7000000
# 300207     Dina Rebaine  Female  2015-03-20      15000000
# 200312  Yahiko Tilemans    Male  2017-05-26      20000000
# 100112    Valter Havers    Male  2018-04-13       7000000
# 200211  Takahiro Momota    Male  2016-11-18      12000000
# 200210    Marko Mendell    Male  2018-07-04      15000000

# %%
df.sort_values(by = ['gender','name'],ascending = [False,True])
# Out:
#                    name  gender   hire date  gross salary
# 200210    Marko Mendell    Male  2018-07-04      15000000
# 200211  Takahiro Momota    Male  2016-11-18      12000000
# 100112    Valter Havers    Male  2018-04-13       7000000
# 200312  Yahiko Tilemans    Male  2017-05-26      20000000
# 300207     Dina Rebaine  Female  2015-03-20      15000000
# 100111    Raven Bierman  Female  2016-12-04       7000000

# %%
df.sort_values(by = ['gender','name'],ascending = [True,True])
# Out:
#                    name  gender   hire date  gross salary
# 300207     Dina Rebaine  Female  2015-03-20      15000000
# 100111    Raven Bierman  Female  2016-12-04       7000000
# 200210    Marko Mendell    Male  2018-07-04      15000000
# 200211  Takahiro Momota    Male  2016-11-18      12000000
# 100112    Valter Havers    Male  2018-04-13       7000000
# 200312  Yahiko Tilemans    Male  2017-05-26      20000000
